# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate Synthetic Data
X = np.arange(10, 30, 0.13)
y = 2.222*X + 3.333

# %%
# Train-Test Split
split = int(len(X)*0.8)
X_train, y_train = X[:split], y[:split]
X_test, y_test = X[split:], y[split:]

# %%
def plot_data(X_train, y_train, X_test, y_test, predictions=None):
    plt.scatter(X_train, y_train, c='b', label='Training Data')
    plt.scatter(X_test, y_test, c='r', label='Testing Data')
    if predictions is not None:
        plt.plot(X_test, predictions, c='g', label='Predictions')
    plt.xlabel('X'); plt.ylabel('y')
    plt.title('X vs y'); plt.legend(); 
    plt.show()

# %%
plot_data(X_train, y_train, X_test, y_test)

# %%
# intialize weights and bias
w = np.random.randn()
b = np.random.randn()
print([w,b])
# Out:
# [-1.7438771110989597, 0.4176876710200435]

# %%
# loss function
def loss_fn(y_actual, y_pred):
    return np.sum(np.square(y_actual - y_pred)) / len(y_actual)

# %%
# Visualize Predictions Before Training
y_out = X_test*w + b
plot_data(X_train, y_train, X_test, y_test, predictions=y_out)

# %%
# Training Loop (Manual Gradient Descent)
lr = 0.1
epochs = 100
train_loss_list, test_loss_list = [], []
for epoch in range(epochs):
    # Forward pass
    train_preds = X_train*w + b
    train_loss = loss_fn(y_train, train_preds)
    # Compute gradients
    gradientW = (-2/len(X_train)) * np.sum((y_train - train_preds)*X_train)
    gradientb = (-2/len(X_train)) * np.sum(y_train - train_preds)
    # Update parameters
    w = w - gradientW*lr
    b = b - gradientb*lr
    # Evaluate on test data
    test_preds = X_test*w + b
    test_loss = loss_fn(y_test, test_preds)
    train_loss_list.append(train_loss)
    test_loss_list.append(test_loss)
# Out:
# /home/dreamer/miniconda3/envs/jarvis/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:83: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# /tmp/ipykernel_3329/3660698508.py:3: RuntimeWarning: overflow encountered in square
#   return np.sum(np.square(y_actual - y_pred)) / len(y_actual)

# %%
# Visualize Predictions After Training
y_out = X_test*w + b
plot_data(X_train, y_train, X_test, y_test, predictions=y_out)
